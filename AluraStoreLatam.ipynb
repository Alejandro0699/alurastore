# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
#Se sumo el total de cada tienda y se imiprimio el resultado.
total_tienda1 = tienda["Precio"].sum()
print(total_tienda1)
total_tienda2 = tienda2["Precio"].sum()
print(total_tienda2)
total_tienda3 = tienda3["Precio"].sum()
print(total_tienda3)
total_tienda4 = tienda4["Precio"].sum()
print(total_tienda4)
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %%
#se genero un grafico de ventas totales por tienda.
Tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
Ventas = [total_tienda1, total_tienda2, total_tienda3, total_tienda4]

plt.bar(Tiendas, Ventas)
plt.title("Ventas Total por tienda")
plt.xlabel("Tiendas")
plt.ylabel("Ventas en $")
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
venta_categoria1= tienda.groupby("Categoría del Producto")["Precio"].sum()
print(venta_categoria1)
venta_categoria2= tienda2.groupby("Categoría del Producto")["Precio"].sum()
print(venta_categoria2)
venta_categoria3= tienda3.groupby("Categoría del Producto")["Precio"].sum()
print(venta_categoria3)
venta_categoria4= tienda4.groupby("Categoría del Producto")["Precio"].sum()
print(venta_categoria4)
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# ...

# %%
#Venta por categoria 1
plt.bar(venta_categoria1.index, venta_categoria1.values, color='skyblue')
plt.title("Categoria del Producto")
plt.xlabel("Ventas por categoría")
plt.ylabel("Ventas en $")
plt.xticks(rotation=45)  # Opcional: rota los nombres para que no se superpongan
plt.tight_layout()       # Opcional: ajusta el gráfico para que todo entre bien
plt.show()

# %%
#Venta por categoria 2
plt.bar(venta_categoria2.index, venta_categoria2.values, color='skyblue')
plt.title("Ventas por categoría")
plt.xlabel("Categoría del Producto")
plt.ylabel("Ventas en $")
plt.xticks(rotation=45)  # Opcional: rota los nombres para que no se superpongan
plt.tight_layout()       # Opcional: ajusta el gráfico para que todo entre bien
plt.show()

# %%
#Venta por categoria 3
plt.bar(venta_categoria3.index, venta_categoria3.values, color='skyblue')
plt.title("Ventas por categoría")
plt.xlabel("Categoría del Producto")
plt.ylabel("Ventas en $")
plt.xticks(rotation=45)  # Opcional: rota los nombres para que no se superpongan
plt.tight_layout()       # Opcional: ajusta el gráfico para que todo entre bien
plt.show()

# %%
#Venta por categoria 4
plt.bar(venta_categoria4.index, venta_categoria4.values, color='skyblue')
plt.title("Ventas por categoría")
plt.xlabel("Categoría del Producto")
plt.ylabel("Ventas en $")
plt.xticks(rotation=45)  # Opcional: rota los nombres para que no se superpongan
plt.tight_layout()       # Opcional: ajusta el gráfico para que todo entre bien
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda1 = tienda["Calificación"].mean()
print(calificacion_tienda1)
califacion_tienda2 = tienda2["Calificación"].mean()
print(califacion_tienda2)
calificacion_tienda3 = tienda3["Calificación"].mean()
print(calificacion_tienda3)
calificacion_tienda4 = tienda4["Calificación"].mean()
print(calificacion_tienda4)
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.9957591178965224

# %%
#Calificacion promedio de los clientes
Tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
Calificacion = [calificacion_tienda1, califacion_tienda2, calificacion_tienda3, calificacion_tienda4]

plt.pie(Calificacion, labels=Tiendas, autopct='%1.1f%%', startangle=90)
plt.title("Calificación de las tiendas")
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_max1=tienda.groupby("Producto")["Precio"].count().idxmax()
print(f"El producto más vendido en la tienda 1 es: {producto_max1}")
producto_min1=tienda.groupby("Producto")["Precio"].count().idxmin()
print(f"El producto menos vendido en la tienda 1 es: {producto_min1}")
producto_max2=tienda2.groupby("Producto")["Precio"].count().idxmax()
print(f"El producto más vendido en la tienda 2 es: {producto_max2}")
producto_min2=tienda2.groupby("Producto")["Precio"].count().idxmin()
print(f"El producto menos vendido en la tienda 2 es: {producto_min2}")
producto_max3=tienda3.groupby("Producto")["Precio"].count().idxmax()
print(f"El producto más vendido en la tienda 3 es: {producto_max3}")
producto_min3=tienda3.groupby("Producto")["Precio"].count().idxmin()
print(f"El producto menos vendido en la tienda 3 es: {producto_min3}")
producto_max4=tienda4.groupby("Producto")["Precio"].count().idxmax()
print(f"El producto más vendido en la tienda 4 es: {producto_max4}")
producto_min4=tienda4.groupby("Producto")["Precio"].count().idxmin()
print(f"El producto menos vendido en la tienda 4 es: {producto_min4}")
# Out:
# El producto más vendido en la tienda 1 es: Armario
# El producto menos vendido en la tienda 1 es: Auriculares con micrófono
# El producto más vendido en la tienda 2 es: Iniciando en programación
# El producto menos vendido en la tienda 2 es: Juego de mesa
# El producto más vendido en la tienda 3 es: Kit de bancas
# El producto menos vendido en la tienda 3 es: Bloques de construcción
# El producto más vendido en la tienda 4 es: Cama box
# El producto menos vendido en la tienda 4 es: Guitarra eléctrica

# %%
#Creando el gaficos para los productos mas y menos vendidos.
productos_mas_vendidos = [producto_max1, producto_max2, producto_max3, producto_max4]
productos_menos_vendidos = [producto_min1, producto_min2, producto_min3, producto_min4]

plt.bar(productos_menos_vendidos)
plt.title("Productos más y menos vendidos")
plt.xlabel("Productos")
plt.ylabel("Ventas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1486f65cc1b6> in <cell line: 0>()
#       3 productos_menos_vendidos = [producto_min1, producto_min2, producto_min3, producto_min4]
#       4
# ----> 5 plt.bar(productos_menos_vendidos)
#       6 plt.title("Productos más y menos vendidos")
#       7 plt.xlabel("Productos")
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
precio_envio1= tienda["Costo de envío"].mean()
print(f"El precio promedio de envío de la tienda 1 es: {precio_envio1}")
precio_envio2= tienda2["Costo de envío"].mean()
print(f"El precio promedio de envío de la tienda 2 es: {precio_envio2}")
precio_envio3= tienda3["Costo de envío"].mean()
print(f"El precio promedio de envío de la tienda 3 es: {precio_envio3}")
precio_envio4= tienda4["Costo de envío"].mean()
print(f"El precio promedio de envío de la tienda 4 es: {precio_envio4}")
# Out:
# El precio promedio de envío de la tienda 1 es: 26018.60958033065
# El precio promedio de envío de la tienda 2 es: 25216.235693090293
# El precio promedio de envío de la tienda 3 es: 24805.680373039424
# El precio promedio de envío de la tienda 4 es: 23459.457167090754

# %%
#Creando el grafico para la media de envios
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
envios = [precio_envio1, precio_envio2, precio_envio3, precio_envio4]

plt.pie(envios, labels=tiendas, autopct='%1.1f%%', startangle=90)
plt.title("Envios promedio por tienda")
plt.show()
